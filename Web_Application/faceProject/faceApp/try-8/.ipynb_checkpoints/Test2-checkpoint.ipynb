# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
from keras.models import load_model
import cv2
import os
import numpy as np
from numpy import expand_dims
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils
import sys
import tensorflow as tf
from mtcnn import MTCNN
import time
detector = MTCNN()
# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=sys.maxsize)

# %%
model = load_model('model/facenet_keras.h5')
print("model Loaded")
for layer in model.layers:
    layer.trianable = False

# %%
loaded_model = model

# %%
def image_to_embedding(image, model): 
    image = cv2.resize(image, (160, 160)) 
    face_pixels = image.astype('float32')
    mean, std = image.mean(), image.std()
    image = (image - mean) / std
    samples = expand_dims(image, axis=0)
    face_embedding = model.predict(samples)
    return face_embedding[0]

# %%
import numpy as np
from mtcnn import MTCNN
from PIL import Image
def extract_face(filename, required_size=(160, 160)):
    face_array = list()
    if  ".ipynb_checkpoints" in filename:
        print(filename)
        pass
    else:
        image = Image.open(filename)
        image = image.convert('RGB')
        pixels = np.asarray(image)
        detector = MTCNN()
        results = detector.detect_faces(pixels)
        x1, y1, width, height = results[0]['box']
        x1, y1 = abs(x1), abs(y1)
        x2, y2 = x1 + width, y1 + height
        face = pixels[y1:y2, x1:x2]
        image = Image.fromarray(face)
        image = image.resize(required_size)
        face_array = np.asarray(image)
    return face_array

# %%
def load_faces(imageDir, label_name):
    faces = list()
    faces_embedding = {}
    for filename in os.listdir(imageDir):
        path = imageDir + filename
        if ".ipynb_checkpoints" in path:
            pass
        else:
            face = extract_face(path)
            print(face.shape)
            face_emd = image_to_embedding(face, loaded_model)
            faces.append(face_emd)
    faces_embedding[label_name] = faces
    return faces, faces_embedding

# %%
import os
import numpy as np
def load_dataset(directory):
    X, y = list(), list()
    faces_embedding = {}
    for subdir in os.listdir(directory):
        path = directory + subdir + '/'
        if  path.startswith('.'):
            pass
        else:
            faces, f = load_faces(path, subdir)
            faces_embedding.update(f)
#             label = [subdir for _ in range(len(faces))]
            print("{} length {}".format(label, len(faces)))
#             dic[label[0]] = faces
            print('>loaded %d examples for class: %s' % (len(faces), subdir))
            X.extend(faces)
            y.extend(label)
#     return X, y, faces_embedding
    return faces_embedding

# %%
def recognize_face(face_image, input_embeddings, model):
    embedding = image_to_embedding(face_image, loaded_model)
    minimum_distance = 200
    name = None
    for (label_name, list_of_images) in input_embeddings.items():
        for image in list_of_images:
            euclidean_distance = np.linalg.norm(embedding-image)
            print('Euclidean distance from %s is %s' %(label_name, euclidean_distance))
            if euclidean_distance < minimum_distance:
                minimum_distance = euclidean_distance
                name = label_name
    if minimum_distance <10:
        return str(name)
    else:
        return "Unknown"

# %%
def recognize_faces_in_cam(input_embeddings):
    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, loaded_model)
            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        key = cv2.waitKey(100)
        cv2.imshow("Deklo Tum Bhi Ab", img)
        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %%
input_embeddings = load_dataset("images/")
# Out:
# (160, 160, 3)
# (160, 160, 3)
# (160, 160, 3)
# (160, 160, 3)
# ['amair', 'amair', 'amair', 'amair'] length 4
# >loaded 4 examples for class: amair
# (160, 160, 3)
# (160, 160, 3)
# ['farhan', 'farhan'] length 2
# >loaded 2 examples for class: farhan

# %%
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from amair is 5.958779
# Euclidean distance from amair is 5.5006046
# Euclidean distance from amair is 5.7556357
# Euclidean distance from amair is 6.0310555
# Euclidean distance from farhan is 14.676161
# Euclidean distance from farhan is 15.2195015
# Euclidean distance from amair is 6.0795135
# Euclidean distance from amair is 5.5928144
# Euclidean distance from amair is 5.9486694
# Euclidean distance from amair is 6.202844
# Euclidean distance from farhan is 14.801185
# Euclidean distance from farhan is 15.16853
# Euclidean distance from amair is 5.7055626
# Euclidean distance from amair is 5.2550216
# Euclidean distance from amair is 5.604162
# Euclidean distance from amair is 5.8926473
# Euclidean distance from farhan is 14.768958
# Euclidean distance from farhan is 15.274722
# Euclidean distance from amair is 6.1421237
# Euclidean distance from amair is 5.647227
# Euclidean distance from amair is 6.003121
# Euclidean distance from amair is 6.3267198
# Euclidean distance from farhan is 14.704808
# Euclidean distance from farhan is 15.041333
# Euclidean distance from amair is 6.443941
# Euclidean distance from amair is 5.930613
# Euclidean distance from amair is 6.188747
# Euclidean distance from amair is 6.53743
# Euclidean distance from farhan is 14.770733
# Euclidean distance from farhan is 15.15588
# Euclidean distance from amair is 6.3452864
# Euclidean distance from amair is 5.88225
# Euclidean distance from amair is 6.1368217
# Euclidean distance from amair is 6.4663806
# Euclidean distance from farhan is 14.697663
# Euclidean distance from farhan is 15.187728
# Euclidean distance from amair is 6.2055745
# Euclidean distance from amair is 5.6829233
# Euclidean distance from amair is 6.04324
# Euclidean distance from amair is 6.310578
# Euclidean distance from farhan is 14.6869955
# Euclidean distance from farhan is 15.191072
# Euclidean distance from amair is 6.061574
# Euclidean distance from amair is 5.4518223
# Euclidean distance from amair is 5.8273177
# Euclidean distance from amair is 6.068722
# Euclidean distance from farhan is 14.595765
# Euclidean distance from farhan is 15.13697
# Euclidean distance from amair is 6.604358
# Euclidean distance from amair is 6.0835037
# Euclidean distance from amair is 6.395948
# Euclidean distance from amair is 6.6774135
# Euclidean distance from farhan is 14.334069
# Euclidean distance from farhan is 14.696147
# Euclidean distance from amair is 6.4339
# Euclidean distance from amair is 6.045339
# Euclidean distance from amair is 6.2571144
# Euclidean distance from amair is 6.500052
# Euclidean distance from farhan is 14.576183
# Euclidean distance from farhan is 15.048022
# Euclidean distance from amair is 6.57908
# Euclidean distance from amair is 6.070463
# Euclidean distance from amair is 6.3599772
# Euclidean distance from amair is 6.6644564
# Euclidean distance from farhan is 14.672391
# Euclidean distance from farhan is 15.162379
# Euclidean distance from amair is 6.4545407
# Euclidean distance from amair is 5.903538
# Euclidean distance from amair is 6.25443
# Euclidean distance from amair is 6.50133
# Euclidean distance from farhan is 14.5658045
# Euclidean distance from farhan is 15.167507
# Euclidean distance from amair is 5.7722626
# Euclidean distance from amair is 5.269088
# Euclidean distance from amair is 5.5871863
# Euclidean distance from amair is 5.789066
# Euclidean distance from farhan is 14.631686
# Euclidean distance from farhan is 15.165493
# Euclidean distance from amair is 5.6722317
# Euclidean distance from amair is 5.1515965
# Euclidean distance from amair is 5.5107546
# Euclidean distance from amair is 5.7245493
# Euclidean distance from farhan is 14.530525
# Euclidean distance from farhan is 15.164363
# Euclidean distance from amair is 6.335071
# Euclidean distance from amair is 5.782022
# Euclidean distance from amair is 6.009526
# Euclidean distance from amair is 6.220422
# Euclidean distance from farhan is 14.203708
# Euclidean distance from farhan is 15.176812
# Euclidean distance from amair is 5.464742
# Euclidean distance from amair is 5.2132816
# Euclidean distance from amair is 5.4381647
# Euclidean distance from amair is 5.4059606
# Euclidean distance from farhan is 14.825667
# Euclidean distance from farhan is 15.621796
# Euclidean distance from amair is 12.9570465
# Euclidean distance from amair is 12.8857765
# Euclidean distance from amair is 12.78421
# Euclidean distance from amair is 13.036293
# Euclidean distance from farhan is 12.725534
# Euclidean distance from farhan is 13.906895
# Euclidean distance from amair is 13.456453
# Euclidean distance from amair is 13.732757
# Euclidean distance from amair is 13.682482
# Euclidean distance from amair is 13.635034
# Euclidean distance from farhan is 17.839872
# Euclidean distance from farhan is 19.01472
# Euclidean distance from amair is 13.633909
# Euclidean distance from amair is 13.757025
# Euclidean distance from amair is 13.820089
# Euclidean distance from amair is 13.91888
# Euclidean distance from farhan is 17.135733
# Euclidean distance from farhan is 18.115551
# Euclidean distance from amair is 14.05748
# Euclidean distance from amair is 14.192695
# Euclidean distance from amair is 14.153203
# Euclidean distance from amair is 14.23455
# Euclidean distance from farhan is 17.57299
# Euclidean distance from farhan is 18.630426
# Euclidean distance from amair is 14.177773
# Euclidean distance from amair is 14.279669
# Euclidean distance from amair is 14.329577
# Euclidean distance from amair is 14.47877
# Euclidean distance from farhan is 17.532549
# Euclidean distance from farhan is 18.706465
# Euclidean distance from amair is 13.038495
# Euclidean distance from amair is 13.1853285
# Euclidean distance from amair is 13.222585
# Euclidean distance from amair is 13.286991
# Euclidean distance from farhan is 17.716019
# Euclidean distance from farhan is 18.690954
# Euclidean distance from amair is 12.620925
# Euclidean distance from amair is 12.720482
# Euclidean distance from amair is 12.788674
# Euclidean distance from amair is 12.878219
# Euclidean distance from farhan is 17.189842
# Euclidean distance from farhan is 18.132673
# Euclidean distance from amair is 12.830435
# Euclidean distance from amair is 12.953771
# Euclidean distance from amair is 12.978634
# Euclidean distance from amair is 13.080391
# Euclidean distance from farhan is 17.273726
# Euclidean distance from farhan is 18.235981
# Euclidean distance from amair is 13.193036
# Euclidean distance from amair is 13.34615
# Euclidean distance from amair is 13.33249
# Euclidean distance from amair is 13.44628
# Euclidean distance from farhan is 17.287563
# Euclidean distance from farhan is 18.308514
# Euclidean distance from amair is 13.172147
# Euclidean distance from amair is 13.30876
# Euclidean distance from amair is 13.310728
# Euclidean distance from amair is 13.426212
# Euclidean distance from farhan is 17.643364
# Euclidean distance from farhan is 18.540375
# Euclidean distance from amair is 13.216612
# Euclidean distance from amair is 13.3452635
# Euclidean distance from amair is 13.354239
# Euclidean distance from amair is 13.468706
# Euclidean distance from farhan is 17.707972
# Euclidean distance from farhan is 18.652
# Euclidean distance from amair is 13.484995
# Euclidean distance from amair is 13.504013
# Euclidean distance from amair is 13.566158
# Euclidean distance from amair is 13.665153
# Euclidean distance from farhan is 17.579855
# Euclidean distance from farhan is 18.477854
# Euclidean distance from amair is 12.826016
# Euclidean distance from amair is 12.938094
# Euclidean distance from amair is 12.921562
# Euclidean distance from amair is 13.077482
# Euclidean distance from farhan is 17.25393
# Euclidean distance from farhan is 18.128363
# Euclidean distance from amair is 7.31237
# Euclidean distance from amair is 7.1513066
# Euclidean distance from amair is 7.0843544
# Euclidean distance from amair is 7.4267178
# Euclidean distance from farhan is 14.364897
# Euclidean distance from farhan is 15.302599
# Euclidean distance from amair is 6.6042275
# Euclidean distance from amair is 6.4955153
# Euclidean distance from amair is 6.6699595
# Euclidean distance from amair is 6.9296904
# Euclidean distance from farhan is 14.833525
# Euclidean distance from farhan is 15.37088
# Euclidean distance from amair is 9.307168
# Euclidean distance from amair is 9.274094
# Euclidean distance from amair is 9.371935
# Euclidean distance from amair is 9.5991955
# Euclidean distance from farhan is 15.258705
# Euclidean distance from farhan is 16.108686
# Euclidean distance from amair is 6.3229055
# Euclidean distance from amair is 6.116367
# Euclidean distance from amair is 6.3597517
# Euclidean distance from amair is 6.696062
# Euclidean distance from farhan is 14.749532
# Euclidean distance from farhan is 15.416503
# Euclidean distance from amair is 6.491186
# Euclidean distance from amair is 6.197169
# Euclidean distance from amair is 6.4858656
# Euclidean distance from amair is 6.9110622
# Euclidean distance from farhan is 15.092341
# Euclidean distance from farhan is 15.615936
# Euclidean distance from amair is 6.305604
# Euclidean distance from amair is 6.1636353
# Euclidean distance from amair is 6.2835374
# Euclidean distance from amair is 6.6904683
# Euclidean distance from farhan is 15.201517
# Euclidean distance from farhan is 15.895371
# Euclidean distance from amair is 7.0072894
# Euclidean distance from amair is 6.9992633
# Euclidean distance from amair is 7.0794945
# Euclidean distance from amair is 7.3911386
# Euclidean distance from farhan is 14.174062
# Euclidean distance from farhan is 14.995733
# Euclidean distance from amair is 13.619403
# Euclidean distance from amair is 13.691231
# Euclidean distance from amair is 13.774717
# Euclidean distance from amair is 13.855812
# Euclidean distance from farhan is 17.110027
# Euclidean distance from farhan is 18.189438
